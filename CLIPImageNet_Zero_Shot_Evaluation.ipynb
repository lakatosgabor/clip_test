# %% [markdown]
# <a href="https://colab.research.google.com/github/lakatosgabor/clip_test/blob/main/CLIPImageNet_Zero_Shot_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U jax jaxlib
# !pip install -q pandas
# !pip install -q ipywidgets
# !pip install -q -U flax
# !pip install -q sentence-transformers
# !pip install -q git+https://github.com/huggingface/transformers.git
# !pip install -q transformers
# !pip install -q torch torchvision

# %%
import os
import sys
import json

import numpy as np
import pandas as pd

os.environ['TOKENIZERS_PARALLELISM'] = "false"

import transformers
from transformers import AutoTokenizer

import torch
import torchvision
from torchvision import transforms
from torchvision.transforms import CenterCrop, ConvertImageDtype, Normalize, Resize, ToTensor
from torchvision.transforms.functional import InterpolationMode
from tqdm.notebook import tqdm

sys.path.append('.')

from modeling_hybrid_clip import FlaxHybridCLIP

# %%
import jax
from jax import numpy as jnp
from transformers import FlaxVisionTextDualEncoderModel

TOKENIZER_NAME = "SZTAKI-HLT/hubert-base-cc"
tokenizer = AutoTokenizer.from_pretrained(TOKENIZER_NAME, cache_dir=None, use_fast=True)
model = FlaxVisionTextDualEncoderModel.from_pretrained("/content/drive/MyDrive/model/5")
def tokenize(texts):
    inputs = tokenizer(texts, max_length=96, padding="max_length", return_tensors="np")
    return inputs['input_ids'], inputs['attention_mask']

language_model = lambda queries: np.asarray(model.get_text_features(*tokenize(queries)))
image_model = lambda images: np.asarray(model.get_image_features(images.permute(0, 2, 3, 1).numpy(),))
# Out:
# You are using a model of type hybrid-clip to instantiate a model of type vision-text-dual-encoder. This is not supported for all configurations of models and can yield errors.
# WARNING:jax._src.xla_bridge:An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
# !wget -N -q https://raw.githubusercontent.com/clip-italian/clip-italian/imagenet_templates/evaluation/imagenet_labels_IT.tsv
classes_df = pd.read_csv('/content/imagenet_data.tsv', sep='\t', header=0)
imagenet_classes = list(classes_df['query_short'])  # list(classes_df['query_long_translated'])
imagenet_templates = [
    'egy fotó {}.',
]

print(f"{len(imagenet_classes)} classes, {len(imagenet_templates)} templates")
# Out:
# 1000 classes, 1 templates

# %%
val_preprocess = transforms.Compose([
    Resize([224], interpolation=InterpolationMode.BICUBIC),
    CenterCrop(224),
    ToTensor(),
    Normalize((0.48145466, 0.4578275, 0.40821073), (0.26862954, 0.26130258, 0.27577711)),
])

# %%
print('Downloading Imagenet validation set...')
# !wget -N -q --show-progress https://image-net.org/data/ILSVRC/2012/ILSVRC2012_img_val.tar
print('Downloading Imagenet devkit...')
# !wget -N -q --show-progress https://image-net.org/data/ILSVRC/2012/ILSVRC2012_devkit_t12.tar.gz
print('Done.')

images = torchvision.datasets.ImageNet('./', split='val', transform=val_preprocess)
loader = torch.utils.data.DataLoader(
    images,
    batch_size=1024,
    shuffle=False,
    num_workers=2,
    persistent_workers=True,
    drop_last=False
)
# Out:
# Downloading Imagenet validation set...
# Downloading Imagenet devkit...
# Done.

# %%
def zeroshot_classifier(classnames, templates):
    zeroshot_weights = []
    for classname in tqdm(classnames):
        texts = [template.format(classname) for template in templates]
        print(texts)
        class_embeddings = language_model(texts)
        class_embeddings = class_embeddings / np.linalg.norm(class_embeddings, axis=-1, keepdims=True)
        class_embedding = np.mean(class_embeddings, axis=0)
        class_embedding /= np.linalg.norm(class_embedding, axis=-1)
        zeroshot_weights.append(class_embedding)
    zeroshot_weights = np.stack(zeroshot_weights, axis=1)
    return zeroshot_weights


zeroshot_weights = zeroshot_classifier(imagenet_classes, imagenet_templates)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ['egy fotó egy tench.']
# ['egy fotó egy aranyhal.']
# ['egy fotó egy nagy fehér cápa.']
# ['egy fotó egy tigriscápa.']
# ['egy fotó egy kalapácsfej.']
# ['egy fotó Egy elektromos sugara.']
# ['egy fotó egy szúrás.']
# ['egy fotó kakas.']
# ['egy fotó egy tyúk.']
# ['egy fotó egy strucc.']
# ['egy fotó egy csapás.']
# ['egy fotó egy aranyfajta.']
# ['egy fotó Ház pinty.']
# ['egy fotó Junco.']
# ['egy fotó egy indigó sármány.']
# ['egy fotó egy robin.']
# ['egy fotó egy bulbul.']
# ['egy fotó A JAY.']
# ['egy fotó egy magpie.']
# ['egy fotó egy csicseriborsó.']
# ['egy fotó egy víz ouzel.']
# ['egy fotó egy sárkány.']
# ['egy fotó Kopasz sas.']
# ['egy fotó keselyű.']
# ['egy fotó egy nagy szürke bagoly.']
# ['egy fotó Európai tűzoltó szalamander.']
# ['egy fotó egy közös newt.']
# ['egy fotó egy eft.']
# ['egy fotó egy foltos szalamander.']
# ['egy fotó egy axolotl.']
# ['egy fotó egy bikabikát.']
# ['egy fotó egy fa béka.']
# ['egy fotó farkú béka.']
# ['egy fotó egy loggerfej.']
# ['egy fotó Bőrös teknős.']
# ['egy fotó egy sár teknős.']
# ['egy fotó egy terrapin.']
# ['egy fotó egy dobozos teknős.']
# ['egy fotó Egy sávos gekkó.']
# ['egy fotó egy közös iguána.']
# ['egy fotó egy amerikai kaméleon.']
# ['egy fotó egy lobogó.']
# ['egy fotó vallás.']
# ['egy fotó egy fodros gyík.']
# ['egy fotó aligátor gyík.']
# ['egy fotó egy gila szörnyeteg.']
# ['egy fotó Egy zöld gyík.']
# ['egy fotó egy afrikai kaméleon.']
# ['egy fotó Komodo sárkány.']
# ['egy fotó egy afrikai krokodil.']
# ['egy fotó amerikai aligátor.']
# ['egy fotó Triceratops.']
# ['egy fotó egy mennydörgés kígyó.']
# ['egy fotó egy ringneck kígyó.']
# ['egy fotó egy hognózus kígyó.']
# ['egy fotó Egy zöld kígyó.']
# ['egy fotó Egy király kígyó.']
# ['egy fotó egy harisnyakötői kígyó.']
# ['egy fotó egy vízkígyó.']
# ['egy fotó egy szőlő kígyó.']
# ['egy fotó Egy éjszakai kígyó.']
# ['egy fotó Boa -szűkítő.']
# ['egy fotó egy szikla python.']
# ['egy fotó Indiai kobrának.']
# ['egy fotó Egy zöld mamba.']
# ['egy fotó egy tengeri kígyó.']
# ['egy fotó egy szarvas vipera.']
# ['egy fotó egy gyémántback.']
# ['egy fotó egy oldalsó.']
# ['egy fotó egy trilobit.']
# ['egy fotó betakarító.']
# ['egy fotó egy skorpió.']
# ['egy fotó Fekete és arany kerti pók.']
# ['egy fotó egy pajta pók.']
# ['egy fotó egy kerti pók.']
# ['egy fotó egy fekete özvegy.']
# ['egy fotó egy tarantula.']
# ['egy fotó egy farkas pók.']
# ['egy fotó kullancs.']
# ['egy fotó egy százlábú.']
# ['egy fotó egy fekete grouse.']
# ['egy fotó egy ptarmigan.']
# ['egy fotó egy fodros grouse.']
# ['egy fotó egy préri csirke.']
# ['egy fotó egy páva.']
# ['egy fotó egy fürj.']
# ['egy fotó egy köpeny.']
# ['egy fotó egy afrikai szürke.']
# ['egy fotó Ara ara.']
# ['egy fotó Egy kénkorú kakatoo.']
# ['egy fotó egy lorikeet.']
# ['egy fotó egy coucal.']
# ['egy fotó egy méhevő.']
# ['egy fotó egy szarv.']
# ['egy fotó egy kolibri.']
# ['egy fotó egy jacamar.']
# ['egy fotó egy tukán.']
# ['egy fotó egy Drake.']
# ['egy fotó egy vörös mellű mergyer.']
# ['egy fotó egy lúd.']
# ['egy fotó Egy fekete hattyú.']
# ['egy fotó egy tusker.']
# ['egy fotó Ah Echidna.']
# ['egy fotó Platypus.']
# ['egy fotó egy wallaby.']
# ['egy fotó Malau.']
# ['egy fotó egy wombat.']
# ['egy fotó egy medúza.']
# ['egy fotó Tengeri nyomaték.']
# ['egy fotó egy agyi korall.']
# ['egy fotó egy lapos féreg.']
# ['egy fotó egy fonálféreg.']
# ['egy fotó egy kagyló.']
# ['egy fotó a csiga.']
# ['egy fotó egy csiga.']
# ['egy fotó egy tengeri csiga.']
# ['egy fotó Egy chiton.']
# ['egy fotó egy kamra nautilus.']
# ['egy fotó egy dungeness rák.']
# ['egy fotó egy szikla rák.']
# ['egy fotó egy hegedű rák.']
# ['egy fotó King Rák.']
# ['egy fotó egy amerikai homár.']
# ['egy fotó egy tüskés homár.']
# ['egy fotó egy rák.']
# ['egy fotó remete rák.']
# ['egy fotó egy izopod.']
# ['egy fotó egy fehér gólya.']
# ['egy fotó egy fekete gólya.']
# ['egy fotó egy kanálszalag.']
# ['egy fotó egy flamingó.']
# ['egy fotó Egy kis kék gém.']
# ['egy fotó egy amerikai kócsag.']
# ['egy fotó egy keserű.']
# ['egy fotó daru.']
# ['egy fotó egy limpin.']
# ['egy fotó egy európai gallinule.']
# ['egy fotó egy amerikai coot.']
# ['egy fotó egy ütés.']
# ['egy fotó egy ruddy fordulókő.']
# ['egy fotó egy vörös hátú homokpiper.']
# ['egy fotó Red -shank.']
# ['egy fotó egy dowitcher.']
# ['egy fotó egy kagylógátló.']
# ['egy fotó egy pelikán.']
# ['egy fotó egy király pingvin.']
# ['egy fotó egy albatrosz.']
# ['egy fotó Egy szürke bálna.']
# ['egy fotó Egy gyilkos bálna.']
# ['egy fotó Adu.']
# ['egy fotó egy tengeri oroszlán.']
# ['egy fotó csivava.']
# ['egy fotó Japán spániel.']
# ['egy fotó egy máltai kutya.']
# ['egy fotó és a pekiness.']
# ['egy fotó És Shih-tzu.']
# ['egy fotó Egy Blenheim spániel.']
# ['egy fotó Egy lepke.']
# ['egy fotó egy játékterrier.']
# ['egy fotó Egy rodosz gerinc.']
# ['egy fotó egy afgán kutya.']
# ['egy fotó egy basszus.']
# ['egy fotó egy Beagle.']
# ['egy fotó egy vérkutya.']
# ['egy fotó egy bluetick.']
# ['egy fotó egy fekete-barnás koonhound.']
# ['egy fotó egy sétáló kutya.']
# ['egy fotó egy angol rókaverék.']
# ['egy fotó Redbone.']
# ['egy fotó egy borzoi.']
# ['egy fotó egy ír farkaskutya.']
# ['egy fotó egy olasz agár.']
# ['egy fotó egy whippet.']
# ['egy fotó Ibizan kutya.']
# ['egy fotó egy norvég jávorszarvas.']
# ['egy fotó egy Otterhound.']
# ['egy fotó Salukiig.']
# ['egy fotó egy skót szarvas.']
# ['egy fotó Weimarerer.']
# ['egy fotó Staffordshire Bullterrier.']
# ['egy fotó egy amerikai Staffordshire -i terrier.']
# ['egy fotó egy bedlingtoni terrier.']
# ['egy fotó Határterrier.']
# ['egy fotó Kerry kék terrier.']
# ['egy fotó egy ír terrier.']
# ['egy fotó Norfolk terrier.']
# ['egy fotó egy norwichi terrier.']
# ['egy fotó egy Yorkshire -i terrier.']
# ['egy fotó egy drótszőrű róka terrier.']
# ['egy fotó egy Lakeland terrier.']
# ['egy fotó egy Sealyham terrier.']
# ['egy fotó Airedale.']
# ['egy fotó Egy cairn.']
# ['egy fotó egy ausztrál terrier.']
# ['egy fotó egy dandie dinmont.']
# ['egy fotó egy bostoni bika.']
# ['egy fotó egy miniatűr schnauzer.']
# ['egy fotó egy óriási schnauzer.']
# ['egy fotó egy standard schnauzer.']
# ['egy fotó egy skót terrier.']
# ['egy fotó egy tibeti terrier.']
# ['egy fotó Egy selymes terrier.']
# ['egy fotó egy lágy bevonatú búza terrier.']
# ['egy fotó Nyugat -hegyvidéki fehér terrier.']
# ['egy fotó Időszak.']
# ['egy fotó egy lapos bevonatú retriever.']
# ['egy fotó göndör bevonatú retriever.']
# ['egy fotó egy arany retriever.']
# ['egy fotó Labrador -retriever.']
# ['egy fotó A Chesapeake -öböl retriever.']
# ['egy fotó Egy német rövid hajú mutató.']
# ['egy fotó a vizsla.']
# ['egy fotó egy angol szetter.']
# ['egy fotó egy ír szetter.']
# ['egy fotó Egy Gordon szetter.']
# ['egy fotó egy brittany spániel.']
# ['egy fotó egy logár.']
# ['egy fotó egy angol springer.']
# ['egy fotó egy walesi springer spániel.']
# ['egy fotó Egy kakas spániel.']
# ['egy fotó egy sussex spániel.']
# ['egy fotó egy ír víz spániel.']
# ['egy fotó a kuvasz.']
# ['egy fotó A Schipperke.']
# ['egy fotó A nyögés.']
# ['egy fotó Egy malinois.']
# ['egy fotó egy briard.']
# ['egy fotó egy welie.']
# ['egy fotó a komondor.']
# ['egy fotó egy régi angol juhászkutya.']
# ['egy fotó egy shetlandi juhászkutya.']
# ['egy fotó egy collie.']
# ['egy fotó Border Collie.']
# ['egy fotó Hogy bouvier des flandres.']
# ['egy fotó egy rottweiler.']
# ['egy fotó egy német pásztor.']
# ['egy fotó egy doberman.']
# ['egy fotó Miniatűr csengő.']
# ['egy fotó egy nagyobb svájci hegyi kutya.']
# ['egy fotó egy berni hegyi kutya.']
# ['egy fotó Egy appenzeller.']
# ['egy fotó és az Unleasuchers.']
# ['egy fotó bokszoló.']
# ['egy fotó Egy bika masztiff.']
# ['egy fotó egy tibeti masztiff.']
# ['egy fotó egy francia bulldog.']
# ['egy fotó egy nagy Dane.']
# ['egy fotó Szent Bernard.']
# ['egy fotó Eskimo kutya.']
# ['egy fotó egy malamut.']
# ['egy fotó egy szibériai husky.']
# ['egy fotó egy dalmát.']
# ['egy fotó Affenpinscher.']
# ['egy fotó A csata idején.']
# ['egy fotó egy mopsz.']
# ['egy fotó és Leonberg.']
# ['egy fotó egy Newfoundland.']
# ['egy fotó Nagy Pireneusok.']
# ['egy fotó egy szamoyed.']
# ['egy fotó egy pomerániai.']
# ['egy fotó egy chow.']
# ['egy fotó egy keeshond.']
# ['egy fotó Brabancon griffon.']
# ['egy fotó egy Pembroke.']
# ['egy fotó egy kardigán.']
# ['egy fotó egy játék uszkár.']
# ['egy fotó egy miniatűr uszkár.']
# ['egy fotó egy standard uszkár.']
# ['egy fotó egy mexikói szőrtelen.']
# ['egy fotó egy fa farkas.']
# ['egy fotó egy fehér farkas.']
# ['egy fotó egy vörös farkas.']
# ['egy fotó egy prérifarkas.']
# ['egy fotó Dingóhoz.']
# ['egy fotó egy fasz.']
# ['egy fotó egy afrikai vadászkutya.']
# ['egy fotó és hiéna.']
# ['egy fotó Vörös róka.']
# ['egy fotó egy készlet róka.']
# ['egy fotó sarkvidéki róka.']
# ['egy fotó Egy szürke róka.']
# ['egy fotó Cirmok.']
# ['egy fotó egy tigrismacska.']
# ['egy fotó Egy perzsa macska.']
# ['egy fotó egy sziámi macska.']
# ['egy fotó Egyiptomi macska.']
# ['egy fotó egy puma.']
# ['egy fotó egy lynx.']
# ['egy fotó egy leopárd.']
# ['egy fotó Hó leopárd.']
# ['egy fotó Jaguarnak.']
# ['egy fotó egy oroszlán.']
# ['egy fotó egy tigris.']
# ['egy fotó egy gepárd.']
# ['egy fotó egy barna medve.']
# ['egy fotó egy amerikai fekete medve.']
# ['egy fotó egy jégmedve.']
# ['egy fotó egy lassú medve.']
# ['egy fotó egy mongúz.']
# ['egy fotó egy meerkat.']
# ['egy fotó egy tigrisbogár.']
# ['egy fotó katicabogár.']
# ['egy fotó egy földi bogár.']
# ['egy fotó egy hosszú szúrós bogár.']
# ['egy fotó egy levélbogár.']
# ['egy fotó egy trágyabogár.']
# ['egy fotó egy orrszarvú bogár.']
# ['egy fotó egy gyomor.']
# ['egy fotó egy légy.']
# ['egy fotó egy méh.']
# ['egy fotó egy hangya.']
# ['egy fotó egy szöcske.']
# ['egy fotó egy krikett.']
# ['egy fotó egy sétabot.']
# ['egy fotó egy csótány.']
# ['egy fotó egy mantis.']
# ['egy fotó Kabóca.']
# ['egy fotó egy leveleshopper.']
# ['egy fotó egy csipkés.']
# ['egy fotó egy szitakötő.']
# ['egy fotó egy damiszkán.']
# ['egy fotó admirális.']
# ['egy fotó egy gyűrűs.']
# ['egy fotó egy uralkodó.']
# ['egy fotó káposztapfajtás.']
# ['egy fotó Egy kén pillangó.']
# ['egy fotó egy lycaenid.']
# ['egy fotó egy tengeri csillag.']
# ['egy fotó egy tengeri sün.']
# ['egy fotó egy tengeri uborka.']
# ['egy fotó egy fa nyúl.']
# ['egy fotó egy mezei nyúl.']
# ['egy fotó Angora az.']
# ['egy fotó egy hörcsög.']
# ['egy fotó sertés.']
# ['egy fotó egy róka mókus.']
# ['egy fotó egy mormot.']
# ['egy fotó egy hód.']
# ['egy fotó egy tengerimalac.']
# ['egy fotó egy sóska.']
# ['egy fotó egy zebra.']
# ['egy fotó egy disznó.']
# ['egy fotó Egy vaddisznó.']
# ['egy fotó egy Warthog.']
# ['egy fotó egy víziló.']
# ['egy fotó ökör.']
# ['egy fotó egy vízi bivaly.']
# ['egy fotó bölény.']
# ['egy fotó egy kos.']
# ['egy fotó egy nagyszülött.']
# ['egy fotó egy ibex.']
# ['egy fotó Egy hartebeest.']
# ['egy fotó egy Impala.']
# ['egy fotó egy gazella.']
# ['egy fotó egy arab teve.']
# ['egy fotó Láng.']
# ['egy fotó egy menyét.']
# ['egy fotó egy nyérc.']
# ['egy fotó Polecat.']
# ['egy fotó egy fekete lábú vadászgörény.']
# ['egy fotó egy vidra.']
# ['egy fotó egy skunk.']
# ['egy fotó egy borz.']
# ['egy fotó Armadillo.']
# ['egy fotó egy háromlábú laza.']
# ['egy fotó orangután.']
# ['egy fotó egy gorilla.']
# ['egy fotó egy csimpánz.']
# ['egy fotó egy gibbon.']
# ['egy fotó Egy siamang.']
# ['egy fotó Guenonban.']
# ['egy fotó lábakra.']
# ['egy fotó pávián.']
# ['egy fotó egy makákó.']
# ['egy fotó Hosszú.']
# ['egy fotó egy kolobusz.']
# ['egy fotó egy proboscis majom.']
# ['egy fotó egy mormozót.']
# ['egy fotó egy kapucinus.']
# ['egy fotó Egy üvöltő majom.']
# ['egy fotó egy tititi.']
# ['egy fotó egy pók majom.']
# ['egy fotó egy mókus majom.']
# ['egy fotó Egy Madagaszkár macska.']
# ['egy fotó az Indri.']
# ['egy fotó egy indiai elefánt.']
# ['egy fotó egy afrikai elefánt.']
# ['egy fotó Kisebb panda.']
# ['egy fotó egy óriási panda.']
# ['egy fotó egy barracouta.']
# ['egy fotó egy angolna.']
# ['egy fotó Coho -hoz.']
# ['egy fotó Egy szikla szépség.']
# ['egy fotó Egy vérfestékes hal.']
# ['egy fotó egy tok.']
# ['egy fotó egy GAR.']
# ['egy fotó egy oroszlánhal.']
# ['egy fotó egy puffer.']
# ['egy fotó Abacus.']
# ['egy fotó Abaya.']
# ['egy fotó tudományos ruha.']
# ['egy fotó harmonika.']
# ['egy fotó Akusztikus gitár.']
# ['egy fotó repülőgép -szállító.']
# ['egy fotó repülőgép.']
# ['egy fotó léghajó.']
# ['egy fotó oltárhoz.']
# ['egy fotó mentőautó.']
# ['egy fotó kétéltű.']
# ['egy fotó analóg óra.']
# ['egy fotó méhész.']
# ['egy fotó Apán.']
# ['egy fotó Ashcan.']
# ['egy fotó támadó puska.']
# ['egy fotó hátizsák.']
# ['egy fotó Pékség.']
# ['egy fotó egyensúlyi gerenda.']
# ['egy fotó egy lufi.']
# ['egy fotó egy labdapróp.']
# ['egy fotó Egy sávsegély.']
# ['egy fotó Egy nyomdát.']
# ['egy fotó egy bannister.']
# ['egy fotó egy súlyzó.']
# ['egy fotó egy fodrászszék.']
# ['egy fotó fodrászat.']
# ['egy fotó gyermek.']
# ['egy fotó barométer.']
# ['egy fotó egy hordó.']
# ['egy fotó egy kavics.']
# ['egy fotó baseball.']
# ['egy fotó Kosárlabda.']
# ['egy fotó egy basszusgitár.']
# ['egy fotó egy gurav.']
# ['egy fotó fürdőkapacka.']
# ['egy fotó egy fürdő törülköző.']
# ['egy fotó kádos.']
# ['egy fotó egy tengerparti kocsi.']
# ['egy fotó jeladó.']
# ['egy fotó egy főzőpoharat.']
# ['egy fotó egy medvebőr.']
# ['egy fotó egy sörüveg.']
# ['egy fotó egy sörpohár.']
# ['egy fotó egy harang cote.']
# ['egy fotó Egy vállpántos.']
# ['egy fotó Kerékpár által épített kettő.']
# ['egy fotó egy bikini.']
# ['egy fotó kötőanyag.']
# ['egy fotó egy távcső.']
# ['egy fotó egy madárház.']
# ['egy fotó egy csónakház.']
# ['egy fotó egy bobossult.']
# ['egy fotó És azok voltak azok.']
# ['egy fotó motorháztető.']
# ['egy fotó egy könyvespolc.']
# ['egy fotó Egy könyvesbolt.']
# ['egy fotó egy palackozás.']
# ['egy fotó íj.']
# ['egy fotó egy csokornyakkendő.']
# ['egy fotó egy sárgaréz.']
# ['egy fotó Brassiera -nak.']
# ['egy fotó egy törésvize.']
# ['egy fotó egy melllapot.']
# ['egy fotó seprű.']
# ['egy fotó egy vödör.']
# ['egy fotó egy csat.']
# ['egy fotó golyóálló mellény.']
# ['egy fotó egy golyóvonat.']
# ['egy fotó hentesbolt.']
# ['egy fotó egy taxi.']
# ['egy fotó egy Caldron.']
# ['egy fotó egy gyertya.']
# ['egy fotó egy ágyú.']
# ['egy fotó egy kenu.']
# ['egy fotó A kanna nyitó.']
# ['egy fotó egy kardigán.']
# ['egy fotó egy autó tükör.']
# ['egy fotó egy körhinta.']
# ['egy fotó ácskészlet.']
# ['egy fotó egy karton.']
# ['egy fotó egy autókerék.']
# ['egy fotó egy pénztárgép.']
# ['egy fotó kazetta.']
# ['egy fotó kazettás lejátszó.']
# ['egy fotó egy kastély.']
# ['egy fotó egy katamarán.']
# ['egy fotó egy CD lejatszó.']
# ['egy fotó egy cselló.']
# ['egy fotó mobiltelefon.']
# ['egy fotó egy lánc.']
# ['egy fotó Chainlink kerítés.']
# ['egy fotó láncposta.']
# ['egy fotó láncfűrész.']
# ['egy fotó mellkas.']
# ['egy fotó egy sifonier.']
# ['egy fotó egy hangjelzés.']
# ['egy fotó Kínai kabinet.']
# ['egy fotó Karácsonyi harisnya.']
# ['egy fotó egy templom.']
# ['egy fotó egy mozi.']
# ['egy fotó egy cleaver.']
# ['egy fotó egy szikla lakás.']
# ['egy fotó egy köpeny.']
# ['egy fotó egy eltömődés.']
# ['egy fotó Egy koktélrázó.']
# ['egy fotó Egy kávé bögre.']
# ['egy fotó egy kávézó.']
# ['egy fotó egy tekercs.']
# ['egy fotó kombinált zár.']
# ['egy fotó Számítógépes billentyűzet.']
# ['egy fotó cukrász.']
# ['egy fotó egy konténerhajó.']
# ['egy fotó konvertibilis.']
# ['egy fotó egy dugóhúzó.']
# ['egy fotó egy cornet.']
# ['egy fotó Cowboy csomagtartó.']
# ['egy fotó egy cowboy kalap.']
# ['egy fotó egy bölcső.']
# ['egy fotó daru.']
# ['egy fotó Egy ütköző sisak.']
# ['egy fotó láda.']
# ['egy fotó egy kiságy.']
# ['egy fotó egy crock edény.']
# ['egy fotó egy krokett golyó.']
# ['egy fotó egy mankó.']
# ['egy fotó egy cuirass.']
# ['egy fotó gát.']
# ['egy fotó íróasztal.']
# ['egy fotó asztali számítógép.']
# ['egy fotó egy telefonszám.']
# ['egy fotó egy pelenka.']
# ['egy fotó Digitális óra.']
# ['egy fotó Digitális óra.']
# ['egy fotó étkezőasztal.']
# ['egy fotó egy dishrag.']
# ['egy fotó egy mosogatógép.']
# ['egy fotó Lemezfék.']
# ['egy fotó egy dokkoló.']
# ['egy fotó egy kutyusos.']
# ['egy fotó egy kupola.']
# ['egy fotó egy ajtógombos.']
# ['egy fotó egy fúrási platform.']
# ['egy fotó egy dob.']
# ['egy fotó egy dobpálca.']
# ['egy fotó egy súlyzó.']
# ['egy fotó egy holland sütő.']
# ['egy fotó egy elektromos ventilátor.']
# ['egy fotó Elektromos gitár.']
# ['egy fotó egy elektromos mozdony.']
# ['egy fotó szórakoztató központ.']
# ['egy fotó boríték.']
# ['egy fotó egy eszpresszó készítő.']
# ['egy fotó arcpor.']
# ['egy fotó A jó toll.']
# ['egy fotó Fájl.']
# ['egy fotó egy tűzhajó.']
# ['egy fotó tűzoltóautó.']
# ['egy fotó tűzképernyő.']
# ['egy fotó Egy zászlórúd.']
# ['egy fotó fuvola.']
# ['egy fotó egy összecsukható szék.']
# ['egy fotó egy labdarúgó -sisak.']
# ['egy fotó targonca.']
# ['egy fotó egy szökőkút.']
# ['egy fotó egy szökőkút toll.']
# ['egy fotó négysoros.']
# ['egy fotó egy teherautó.']
# ['egy fotó egy francia kürt.']
# ['egy fotó egy serpenyő.']
# ['egy fotó egy szőrmekabát.']
# ['egy fotó egy szemétkocsi.']
# ['egy fotó egy Gasmask.']
# ['egy fotó egy gázszivattyú.']
# ['egy fotó egy serleget.']
# ['egy fotó egy gokart.']
# ['egy fotó egy golflabda.']
# ['egy fotó egy golfkocsi.']
# ['egy fotó egy gondola.']
# ['egy fotó Nagypapa.']
# ['egy fotó ruha.']
# ['egy fotó egy nagy zongora.']
# ['egy fotó üvegház.']
# ['egy fotó egy rács.']
# ['egy fotó egy élelmiszerbolt.']
# ['egy fotó giljotin.']
# ['egy fotó egy hajlemez.']
# ['egy fotó haj spray.']
# ['egy fotó egy félpályás.']
# ['egy fotó egy kalapács.']
# ['egy fotó akadály.']
# ['egy fotó egy kézfúvó.']
# ['egy fotó egy kézi számítógép.']
# ['egy fotó egy zsebkendő.']
# ['egy fotó egy kemény lemez.']
# ['egy fotó egy harmonikus.']
# ['egy fotó egy hárfa.']
# ['egy fotó kombájn.']
# ['egy fotó egy csapda.']
# ['egy fotó egy tok.']
# ['egy fotó házimozi.']
# ['egy fotó egy méhsejt.']
# ['egy fotó egy horog.']
# ['egy fotó egy karika.']
# ['egy fotó egy vízszintes sáv.']
# ['egy fotó egy lókocsi.']
# ['egy fotó egy homokóra.']
# ['egy fotó egy iPod.']
# ['egy fotó egy vasat.']
# ["egy fotó Jack-o'-lámpás."]
# ['egy fotó egy farmer.']
# ['egy fotó egy dzsip.']
# ['egy fotó és Jersey.']
# ['egy fotó egy kirakós kirakós puzzle.']
# ['egy fotó Egy riksa.']
# ['egy fotó Joystick.']
# ['egy fotó Kimonó.']
# ['egy fotó egy térdpárna.']
# ['egy fotó egy csomó.']
# ['egy fotó laboratóriumi kabát.']
# ['egy fotó egy kanál.']
# ['egy fotó egy lámpaernyőt.']
# ['egy fotó egy laptop.']
# ['egy fotó egy fűnyíró.']
# ['egy fotó egy lencse sapka.']
# ['egy fotó Levélnyitó.']
# ['egy fotó Könyvtár.']
# ['egy fotó mentőcsónak.']
# ['egy fotó egy öngyújtó.']
# ['egy fotó limuzin.']
# ['egy fotó bélés.']
# ['egy fotó rúzs.']
# ['egy fotó egy hódító.']
# ['egy fotó egy krém.']
# ['egy fotó hangszóró.']
# ['egy fotó nagyító.']
# ['egy fotó egy favágó.']
# ['egy fotó mágneses iránytű.']
# ['egy fotó egy postazsák.']
# ['egy fotó egy postafiók.']
# ['egy fotó egy maillot.']
# ['egy fotó egy maillot.']
# ['egy fotó egy búcsúfedet.']
# ['egy fotó a maraka.']
# ['egy fotó egy marimba.']
# ['egy fotó egy maszk.']
# ['egy fotó egy gyufaszál.']
# ['egy fotó Maypole.']
# ['egy fotó Keverék.']
# ['egy fotó egy mérőpohár.']
# ['egy fotó egy gyógyszerláda.']
# ['egy fotó egy megalit.']
# ['egy fotó egy mikrofon.']
# ['egy fotó egy mikrohullámúsütő.']
# ['egy fotó katonai egyenruh.']
# ['egy fotó egy tej doboz.']
# ['egy fotó Egy minibusz.']
# ['egy fotó Miniszknya.']
# ['egy fotó egy kisbusz.']
# ['egy fotó rakéta.']
# ['egy fotó egy kesztyű.']
# ['egy fotó egy keverő tál.']
# ['egy fotó egy mobilház.']
# ['egy fotó A T modell t.']
# ['egy fotó egy modem.']
# ['egy fotó kolostor.']
# ['egy fotó egy monitor.']
# ['egy fotó egy moped.']
# ['egy fotó Habarcshoz.']
# ['egy fotó egy habarcs.']
# ['egy fotó egy mecset.']
# ['egy fotó egy szúnyogháló.']
# ['egy fotó egy motoros robogó.']
# ['egy fotó egy hegyi kerékpár.']
# ['egy fotó egy hegyi sátor.']
# ['egy fotó egy egér.']
# ['egy fotó egy egér.']
# ['egy fotó egy mozgó kisteherautó.']
# ['egy fotó egy pofa.']
# ['egy fotó Egy köröm.']
# ['egy fotó egy nyaki zárójel.']
# ['egy fotó egy nyaklánc.']
# ['egy fotó egy mellbimbó.']
# ['egy fotó füzet.']
# ['egy fotó egy obeliszk.']
# ['egy fotó És oboa.']
# ['egy fotó egy ocarina.']
# ['egy fotó kilométer -számláló.']
# ['egy fotó olajszűrő.']
# ['egy fotó egy szerv.']
# ['egy fotó oszcilloszkóp.']
# ['egy fotó egy túlfutó.']
# ['egy fotó egy oxcart.']
# ['egy fotó oxigénmaszk.']
# ['egy fotó egy csomag.']
# ['egy fotó egy lapát.']
# ['egy fotó egy padderek.']
# ['egy fotó egy lakat.']
# ['egy fotó egy ecset.']
# ['egy fotó A többiem.']
# ['egy fotó egy palota.']
# ['egy fotó egy lappipe.']
# ['egy fotó Papír törülköző.']
# ['egy fotó ejtőernyős.']
# ['egy fotó Párhuzamos rudak.']
# ['egy fotó egy parkpad.']
# ['egy fotó egy parkolómérő.']
# ['egy fotó személygépkocsi.']
# ['egy fotó egy terasz.']
# ['egy fotó fizető telefon.']
# ['egy fotó egy talapzat.']
# ['egy fotó egy ceruzadoboz.']
# ['egy fotó egy ceruzahegyező.']
# ['egy fotó parfüm.']
# ['egy fotó Petri -csésze.']
# ['egy fotó egy fénymásoló.']
# ['egy fotó egy választás.']
# ['egy fotó egy pickelhaube.']
# ['egy fotó egy piketkerítés.']
# ['egy fotó egy pickup.']
# ['egy fotó egy móló.']
# ['egy fotó egy malacka bank.']
# ['egy fotó egy tabletta palack.']
# ['egy fotó egy párna.']
# ['egy fotó egy ping-pong labda.']
# ['egy fotó egy pinkerék.']
# ['egy fotó egy kalóz.']
# ['egy fotó kancsó.']
# ['egy fotó egy repülő.']
# ['egy fotó egy planetárium.']
# ['egy fotó egy műanyag zacskó.']
# ['egy fotó egy tányér állvány.']
# ['egy fotó egy eke.']
# ['egy fotó egy dugattyú.']
# ['egy fotó Polaroid kamera.']
# ['egy fotó egy rúd.']
# ['egy fotó a police van.']
# ['egy fotó Ah Poncho.']
# ['egy fotó egy biliárdasztal.']
# ['egy fotó egy pop palack.']
# ['egy fotó egy doboz.']
# ['egy fotó Egy fazekaskerék.']
# ['egy fotó egy erőfúró.']
# ['egy fotó egy ima szőnyeg.']
# ['egy fotó egy nyomtató.']
# ['egy fotó egy börtön.']
# ['egy fotó egy lövedék.']
# ['egy fotó kivetítő.']
# ['egy fotó egy korong.']
# ['egy fotó egy lyukasztó táska.']
# ['egy fotó pénztárca.']
# ['egy fotó egy tekercs.']
# ['egy fotó paplan.']
# ['egy fotó versenyző.']
# ['egy fotó ütő.']
# ['egy fotó radiátor.']
# ['egy fotó egy rádió.']
# ['egy fotó egy rádió távcső.']
# ['egy fotó egy esőhordó.']
# ['egy fotó egy szabadidős jármű.']
# ['egy fotó tekercs.']
# ['egy fotó Reflex kamera.']
# ['egy fotó egy hűtőszekrény.']
# ['egy fotó távirányító.']
# ['egy fotó egy étterem.']
# ['egy fotó egy revolver.']
# ['egy fotó puska.']
# ['egy fotó egy hintaszék.']
# ['egy fotó egy rotisserie.']
# ['egy fotó egy gumi radír.']
# ['egy fotó egy rögbi labda.']
# ['egy fotó egy szabály.']
# ['egy fotó Futócipő.']
# ['egy fotó egy széf.']
# ['egy fotó Biztonsági csap.']
# ['egy fotó egy sós haker.']
# ['egy fotó egy szandál.']
# ['egy fotó egy szarong.']
# ['egy fotó szaxofon.']
# ['egy fotó egy ropogós.']
# ['egy fotó egy skála.']
# ['egy fotó iskolabusz.']
# ['egy fotó egy schooner.']
# ['egy fotó Obólapot.']
# ['egy fotó egy képernyő.']
# ['egy fotó Egy csavart.']
# ['egy fotó egy csavarhúzó.']
# ['egy fotó biztonsági öv.']
# ['egy fotó varrógép.']
# ['egy fotó pajzs.']
# ['egy fotó egy cipőbolt.']
# ['egy fotó Szájpadlás.']
# ['egy fotó bevásárlókosár.']
# ['egy fotó egy kosár.']
# ['egy fotó egy ásó.']
# ['egy fotó zuhanysapka.']
# ['egy fotó Egy zuhanyfüggöny.']
# ['egy fotó síelni.']
# ['egy fotó símaszk.']
# ['egy fotó egy hálózsák.']
# ['egy fotó diavetítés.']
# ['egy fotó tolóajtó.']
# ['egy fotó egy rés.']
# ['egy fotó egy légzőcső.']
# ['egy fotó egy motoros.']
# ['egy fotó Hósav.']
# ['egy fotó egy szappan adagoló.']
# ['egy fotó focigolyó.']
# ['egy fotó egy zokni.']
# ['egy fotó egy napelemes étel.']
# ['egy fotó kalaphoz.']
# ['egy fotó egy levestej.']
# ['egy fotó egy űrrúd.']
# ['egy fotó egy űrmelegítő.']
# ['egy fotó egy űrsikló.']
# ['egy fotó egy spatula.']
# ['egy fotó egy motorcsónak.']
# ['egy fotó egy pókháló.']
# ['egy fotó egy orsó.']
# ['egy fotó egy sportautó.']
# ['egy fotó egy reflektorfény.']
# ['egy fotó egy színpad.']
# ['egy fotó gőzmozdony.']
# ['egy fotó egy acél ívhíd.']
# ['egy fotó egy acéldob.']
# ['egy fotó sztetoszkóp.']
# ['egy fotó lopott.']
# ['egy fotó egy kőfal.']
# ['egy fotó egy stopper.']
# ['egy fotó kályha.']
# ['egy fotó szűrő.']
# ['egy fotó Streetcar.']
# ['egy fotó egy hordágy.']
# ['egy fotó egy stúdió kanapé.']
# ['egy fotó egy oszlop.']
# ['egy fotó tengeralattjáró.']
# ['egy fotó öltöny.']
# ['egy fotó napóra.']
# ['egy fotó egy napszemüveg.']
# ['egy fotó napszemüveg.']
# ['egy fotó egy fényvédő.']
# ['egy fotó egy függőhíd.']
# ['egy fotó egy tampon.']
# ['egy fotó egy pulóver.']
# ['egy fotó úszónadrág.']
# ['egy fotó egy hinta.']
# ['egy fotó egy kapcsoló.']
# ['egy fotó fecskendő.']
# ['egy fotó asztali lámpa.']
# ['egy fotó egy tank.']
# ['egy fotó szalagos lejátszó.']
# ['egy fotó egy teáskanna.']
# ['egy fotó egy mackó.']
# ['egy fotó Televízió.']
# ['egy fotó egy teniszlabda.']
# ['egy fotó nádtető.']
# ['egy fotó színházi függöny.']
# ['egy fotó gyűszű.']
# ['egy fotó egy csapda.']
# ['egy fotó egy trón.']
# ['egy fotó csempe tető.']
# ['egy fotó kenyérpirító.']
# ['egy fotó dohánybolt.']
# ['egy fotó WC -ülés.']
# ['egy fotó egy fáklya.']
# ['egy fotó egy totem pólus.']
# ['egy fotó egy vontató teherautó.']
# ['egy fotó egy toyshop.']
# ['egy fotó traktor.']
# ['egy fotó egy pótkocsi teherautó.']
# ['egy fotó egy tálca.']
# ['egy fotó árokkabát.']
# ['egy fotó egy tricikli.']
# ['egy fotó Trimarannak.']
# ['egy fotó egy állvány.']
# ['egy fotó diadal ív.']
# ['egy fotó egy kocsi.']
# ['egy fotó a harsona.']
# ['egy fotó Egy fiú.']
# ['egy fotó egy forduló.']
# ['egy fotó írógép billentyűzet.']
# ['egy fotó Esernyő.']
# ['egy fotó egykerekű.']
# ['egy fotó egy függőleges.']
# ['egy fotó vákuum.']
# ['egy fotó váza.']
# ['egy fotó egy boltozat.']
# ['egy fotó bársony.']
# ['egy fotó egy automata.']
# ['egy fotó mellény.']
# ['egy fotó egy viadukt.']
# ['egy fotó egy hegedű.']
# ['egy fotó röplabda.']
# ['egy fotó egy gofrivas.']
# ['egy fotó A falióra.']
# ['egy fotó pénztárca.']
# ['egy fotó egy szekrény.']
# ['egy fotó harci sík.']
# ['egy fotó egy mosdót.']
# ['egy fotó alátét.']
# ['egy fotó egy vizes palack.']
# ['egy fotó egy vízkanna.']
# ['egy fotó egy víztorony.']
# ['egy fotó egy whisky kancsó.']
# ['egy fotó egy fütyülés.']
# ['egy fotó egy parókát.']
# ['egy fotó ablak képernyő.']
# ['egy fotó egy ablakárnyalat.']
# ['egy fotó Windsor -nyakkendő.']
# ['egy fotó borosüveg.']
# ['egy fotó szárny.']
# ['egy fotó egy wok.']
# ['egy fotó egy fakanál.']
# ['egy fotó gyapjú.']
# ['egy fotó egy féregkerítés.']
# ['egy fotó egy roncs.']
# ['egy fotó egy jawl.']
# ['egy fotó Kollégiumi.']
# ['egy fotó egy weboldal.']
# ['egy fotó egy képregény.']
# ['egy fotó egy keresztrejtvény.']
# ['egy fotó egy utcai jel.']
# ['egy fotó lámpatest.']
# ['egy fotó Egy könyvkabát.']
# ['egy fotó egy menü.']
# ['egy fotó egy tányér.']
# ['egy fotó egy guacamole.']
# ['egy fotó Egy fogyasztás.']
# ['egy fotó egy forró doboz.']
# ['egy fotó egy apróság.']
# ['egy fotó fagylalt.']
# ['egy fotó egy jég lolly.']
# ['egy fotó egy francia kenyér.']
# ['egy fotó egy bagel.']
# ['egy fotó egy perec.']
# ['egy fotó egy sajtburger.']
# ['egy fotó egy hot dog.']
# ['egy fotó egy burgonyapürét.']
# ['egy fotó egy fej káposzta.']
# ['egy fotó egy brokkoli.']
# ['egy fotó egy karfiol.']
# ['egy fotó A cukkini.']
# ['egy fotó egy spagetti tök.']
# ['egy fotó egy makk squash.']
# ['egy fotó egy butternut squash.']
# ['egy fotó egy uborka.']
# ['egy fotó egy articsóka.']
# ['egy fotó Egy harangpaprika.']
# ['egy fotó egy kardon.']
# ['egy fotó gomba.']
# ['egy fotó egy nagyi Smith.']
# ['egy fotó egy eper.']
# ['egy fotó egy narancs.']
# ['egy fotó egy citrom.']
# ['egy fotó egy füge.']
# ['egy fotó egy ananász.']
# ['egy fotó egy banán.']
# ['egy fotó Jackfruit.']
# ['egy fotó egy puding alma.']
# ['egy fotó gránátalma.']
# ['egy fotó vannak.']
# ['egy fotó egy carbonara.']
# ['egy fotó Egy csokoládé szósz.']
# ['egy fotó egy tészta.']
# ['egy fotó Egy húsos kenyér.']
# ['egy fotó egy pizza.']
# ['egy fotó egy potpie.']
# ['egy fotó Elrontó.']
# ['egy fotó Vörösbor.']
# ['egy fotó az eszpresszó.']
# ['egy fotó egy csésze.']
# ['egy fotó egy eggnog.']
# ['egy fotó egy ALP.']
# ['egy fotó egy buborék.']
# ['egy fotó egy szikla.']
# ['egy fotó egy korallzátony.']
# ['egy fotó gejzír.']
# ['egy fotó egy tóparti.']
# ['egy fotó egy hegység.']
# ['egy fotó egy homokozó.']
# ['egy fotó egy tengerpart.']
# ['egy fotó egy völgy.']
# ['egy fotó egy vulkán.']
# ['egy fotó labdajátékos.']
# ['egy fotó vőlegény.']
# ['egy fotó Egy búvár.']
# ['egy fotó egy nemi repce.']
# ['egy fotó egy százszorszép.']
# ['egy fotó Egy sárga hölgy papucs.']
# ['egy fotó kukorica.']
# ['egy fotó makk.']
# ['egy fotó csípő.']
# ['egy fotó egy buckeye.']
# ['egy fotó egy korallgomba.']
# ['egy fotó egy agarikus.']
# ['egy fotó egy giromitra.']
# ['egy fotó egy büdös.']
# ['egy fotó egy földi.']
# ['egy fotó egy fa tyúk.']
# ['egy fotó a bolete.']
# ['egy fotó egy fül.']
# ['egy fotó WC papír.']

# %%
def accuracy(output, target, topk=(1,)):
    output = torch.from_numpy(np.asarray(output))
    target = torch.from_numpy(np.asarray(target))
    pred = output.topk(max(topk), dim=1, largest=True, sorted=True)[1].t()
    correct = pred.eq(target.view(1, -1).expand_as(pred))
    return [float(correct[:k].reshape(-1).float().sum(0, keepdim=True).cpu().numpy()) for k in topk]

# %%
top_ns = [1, 5, 10, 100]
acc_counters = [0. for _ in top_ns]
n = 0.

for i, (images, target) in enumerate(tqdm(loader)):
    images = images
    target = target.numpy()
    # predict
    image_features = image_model(images)
    image_features = image_features / np.linalg.norm(image_features, axis=-1, keepdims=True)
    logits = 100. * image_features @ zeroshot_weights

    # measure accuracy
    accs = accuracy(logits, target, topk=top_ns)
    for j in range(len(top_ns)):
        acc_counters[j] += accs[j]
    n += images.shape[0]

tops = {f'top{top_ns[i]}': acc_counters[i] / n * 100 for i in range(len(top_ns))}

print(tops)
# Out:
#   0%|          | 0/49 [00:00<?, ?it/s]
# {'top1': 0.9119999999999999, 'top5': 3.9899999999999998, 'top10': 7.013999999999999, 'top100': 33.879999999999995}
